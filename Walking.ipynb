# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
env = make_vec_env('Humanoid-v3', n_envs=4)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-eaf258f97eea> in <module>
# ----> 1 env = make_vec_env('Humanoid-v3', n_envs=4)
#
# ~/anaconda3/lib/python3.7/site-packages/stable_baselines/common/cmd_util.py in make_vec_env(env_id, n_envs, seed, start_index, monitor_dir, wrapper_class, env_kwargs, vec_env_cls, vec_env_kwargs)
#      70         vec_env_cls = DummyVecEnv
#      71
# ---> 72     return vec_env_cls([make_env(i + start_index) for i in range(n_envs)], **vec_env_kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.7/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in __init__(self, env_fns)
#      19
#      20     def __init__(self, env_fns):
# ---> 21         self.envs = [fn() for fn in env_fns]
#      22         env = self.envs[0]
#      23         VecEnv.__init__(self, len(env_fns), env.observation_space, env.action_space)
#
# ~/anaconda3/lib/python3.7/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in <listcomp>(.0)
#      19
#      20     def __init__(self, env_fns):
# ---> 21         self.envs = [fn() for fn in env_fns]
#      22         env = self.envs[0]
#      23         VecEnv.__init__(self, len(env_fns), env.observation_space, env.action_space)
#
# ~/anaconda3/lib/python3.7/site-packages/stable_baselines/common/cmd_util.py in _init()
#      44         def _init():
#      45             if isinstance(env_id, str):
# ---> 46                 env = gym.make(env_id)
#      47                 if len(env_kwargs) > 0:
#      48                     warnings.warn("No environment class was passed (only an env ID) so `env_kwargs` will be ignored")
#
# ~/anaconda3/lib/python3.7/site-packages/gym/envs/registration.py in make(id, **kwargs)
#     154
#     155 def make(id, **kwargs):
# --> 156     return registry.make(id, **kwargs)
#     157
#     158 def spec(id):
#
# ~/anaconda3/lib/python3.7/site-packages/gym/envs/registration.py in make(self, path, **kwargs)
#      99             logger.info('Making new env: %s', path)
#     100         spec = self.spec(path)
# --> 101         env = spec.make(**kwargs)
#     102         # We used to have people override _reset/_step rather than
#     103         # reset/step. Set _gym_disable_underscore_compat = True on
#
# ~/anaconda3/lib/python3.7/site-packages/gym/envs/registration.py in make(self, **kwargs)
#      70             env = self.entry_point(**_kwargs)
#      71         else:
# ---> 72             cls = load(self.entry_point)
#      73             env = cls(**_kwargs)
#      74
#
# ~/anaconda3/lib/python3.7/site-packages/gym/envs/registration.py in load(name)
#      15 def load(name):
#      16     mod_name, attr_name = name.split(":")
# ---> 17     mod = importlib.import_module(mod_name)
#      18     fn = getattr(mod, attr_name)
#      19     return fn
#
# ~/anaconda3/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/anaconda3/lib/python3.7/site-packages/gym/envs/mujoco/__init__.py in <module>
# ----> 1 from gym.envs.mujoco.mujoco_env import MujocoEnv
#       2 # ^^^^^ so that user gets the correct error
#       3 # message if mujoco is not installed correctly
#       4 from gym.envs.mujoco.ant import AntEnv
#       5 from gym.envs.mujoco.half_cheetah import HalfCheetahEnv
#
# ~/anaconda3/lib/python3.7/site-packages/gym/envs/mujoco/mujoco_env.py in <module>
#      10
#      11 try:
# ---> 12     import mujoco_py
#      13 except ImportError as e:
#      14     raise error.DependencyNotInstalled("{}. (HINT: you need to install mujoco_py, and also perform the setup instructions here: https://github.com/openai/mujoco-py/.)".format(e))
#
# ~/mujoco-py/mujoco_py/__init__.py in <module>
#       1 #!/usr/bin/env python
#       2 import os
# ----> 3 from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#       4 from mujoco_py.generated import const
#       5 from mujoco_py.mjrenderpool import MjRenderPool
#
# ~/mujoco-py/mujoco_py/builder.py in <module>
#     508
#     509 mujoco_path, key_path = discover_mujoco()
# --> 510 cymj = load_cython_ext(mujoco_path)
#     511
#     512
#
# ~/mujoco-py/mujoco_py/builder.py in load_cython_ext(mujoco_path)
#      67         Builder = MacExtensionBuilder
#      68     elif sys.platform == 'linux':
# ---> 69         _ensure_set_env_var("LD_LIBRARY_PATH", lib_path)
#      70         if os.getenv('MUJOCO_PY_FORCE_CPU') is None and get_nvidia_lib_dir() is not None:
#      71             _ensure_set_env_var("LD_LIBRARY_PATH", get_nvidia_lib_dir())
#
# ~/mujoco-py/mujoco_py/builder.py in _ensure_set_env_var(var_name, lib_path)
#     117                         "Please add following line to .bashrc:\n"
#     118                         "export %s=$%s:%s" % (var_name, os.environ.get(var_name, ""),
# --> 119                                               var_name, var_name, lib_path))
#     120
#     121
#
# Exception:
# Missing path to your environment variable.
# Current values LD_LIBRARY_PATH=
# Please add following line to .bashrc:
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/mike/.mujoco/mujoco200/bin

# %%
model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=25000)
model.save("humanoid")
# Out:
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/common/distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:240: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/mike/anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# -------------------------------------
# | approxkl           | 0.0013531864 |
# | clipfrac           | 0.0053710938 |
# | ep_len_mean        | 22.1         |
# | ep_reward_mean     | 108          |
# | explained_variance | -0.000939    |
# | fps                | 814          |
# | n_updates          | 1            |
# | policy_entropy     | 24.123165    |
# | policy_loss        | -0.021129815 |
# | serial_timesteps   | 128          |
# | time_elapsed       | 1.96e-05     |
# | total_timesteps    | 512          |
# | value_loss         | 936.0394     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0007487957 |
# | clipfrac           | 0.0009765625 |
# | ep_len_mean        | 21.8         |
# | ep_reward_mean     | 106          |
# | explained_variance | -0.000443    |
# | fps                | 1401         |
# | n_updates          | 2            |
# | policy_entropy     | 24.129272    |
# | policy_loss        | -0.011153801 |
# | serial_timesteps   | 256          |
# | time_elapsed       | 0.629        |
# | total_timesteps    | 1024         |
# | value_loss         | 837.0461     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0007049778 |
# | clipfrac           | 0.0024414062 |
# | ep_len_mean        | 22           |
# | ep_reward_mean     | 107          |
# | explained_variance | 1.06e-05     |
# | fps                | 1404         |
# | n_updates          | 3            |
# | policy_entropy     | 24.13479     |
# | policy_loss        | -0.010801429 |
# | serial_timesteps   | 384          |
# | time_elapsed       | 0.995        |
# | total_timesteps    | 1536         |
# | value_loss         | 870.8253     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00082295487 |
# | clipfrac           | 0.0014648438  |
# | ep_len_mean        | 22.3          |
# | ep_reward_mean     | 109           |
# | explained_variance | 0.00846       |
# | fps                | 1290          |
# | n_updates          | 4             |
# | policy_entropy     | 24.139536     |
# | policy_loss        | -0.009163459  |
# | serial_timesteps   | 512           |
# | time_elapsed       | 1.36          |
# | total_timesteps    | 2048          |
# | value_loss         | 1014.50116    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0006996575 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 22           |
# | ep_reward_mean     | 107          |
# | explained_variance | 0.0105       |
# | fps                | 1452         |
# | n_updates          | 5            |
# | policy_entropy     | 24.141981    |
# | policy_loss        | -0.010738466 |
# | serial_timesteps   | 640          |
# | time_elapsed       | 1.76         |
# | total_timesteps    | 2560         |
# | value_loss         | 792.6108     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0008093162 |
# | clipfrac           | 0.001953125  |
# | ep_len_mean        | 22.1         |
# | ep_reward_mean     | 108          |
# | explained_variance | 0.00721      |
# | fps                | 1419         |
# | n_updates          | 6            |
# | policy_entropy     | 24.147402    |
# | policy_loss        | -0.009713359 |
# | serial_timesteps   | 768          |
# | time_elapsed       | 2.11         |
# | total_timesteps    | 3072         |
# | value_loss         | 860.227      |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00072085974 |
# | clipfrac           | 0.00048828125 |
# | ep_len_mean        | 22            |
# | ep_reward_mean     | 107           |
# | explained_variance | 0.019         |
# | fps                | 1376          |
# | n_updates          | 7             |
# | policy_entropy     | 24.155804     |
# | policy_loss        | -0.009267983  |
# | serial_timesteps   | 896           |
# | time_elapsed       | 2.47          |
# | total_timesteps    | 3584          |
# | value_loss         | 783.2875      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00074159785 |
# | clipfrac           | 0.00048828125 |
# | ep_len_mean        | 21.2          |
# | ep_reward_mean     | 103           |
# | explained_variance | 0.0108        |
# | fps                | 1483          |
# | n_updates          | 8             |
# | policy_entropy     | 24.170353     |
# | policy_loss        | -0.007088363  |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 2.84          |
# | total_timesteps    | 4096          |
# | value_loss         | 810.22644     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00092828216 |
# | clipfrac           | 0.0014648438  |
# | ep_len_mean        | 21.4          |
# | ep_reward_mean     | 104           |
# | explained_variance | 0.0207        |
# | fps                | 1402          |
# | n_updates          | 9             |
# | policy_entropy     | 24.186966     |
# | policy_loss        | -0.008220504  |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 3.19          |
# | total_timesteps    | 4608          |
# | value_loss         | 801.4704      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012089213  |
# | clipfrac           | 0.0009765625  |
# | ep_len_mean        | 21.8          |
# | ep_reward_mean     | 106           |
# | explained_variance | 0.00585       |
# | fps                | 1429          |
# | n_updates          | 10            |
# | policy_entropy     | 24.197382     |
# | policy_loss        | -0.0082393605 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 3.56          |
# | total_timesteps    | 5120          |
# | value_loss         | 931.5648      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00093697465 |
# | clipfrac           | 0.0014648438  |
# | ep_len_mean        | 22            |
# | ep_reward_mean     | 107           |
# | explained_variance | 0.0191        |
# | fps                | 1427          |
# | n_updates          | 11            |
# | policy_entropy     | 24.21157      |
# | policy_loss        | -0.004536355  |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 3.92          |
# | total_timesteps    | 5632          |
# | value_loss         | 855.07416     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0013177672 |
# | clipfrac           | 0.0029296875 |
# | ep_len_mean        | 22           |
# | ep_reward_mean     | 107          |
# | explained_variance | 0.0233       |
# | fps                | 1421         |
# | n_updates          | 12           |
# | policy_entropy     | 24.217747    |
# | policy_loss        | -0.00664478  |
# | serial_timesteps   | 1536         |
# | time_elapsed       | 4.27         |
# | total_timesteps    | 6144         |
# | value_loss         | 737.6627     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0013679862  |
# | clipfrac           | 0.0063476562  |
# | ep_len_mean        | 22.6          |
# | ep_reward_mean     | 110           |
# | explained_variance | 0.00595       |
# | fps                | 1380          |
# | n_updates          | 13            |
# | policy_entropy     | 24.233799     |
# | policy_loss        | -0.0075140414 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 4.64          |
# | total_timesteps    | 6656          |
# | value_loss         | 850.87115     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019038576  |
# | clipfrac           | 0.0068359375  |
# | ep_len_mean        | 22            |
# | ep_reward_mean     | 108           |
# | explained_variance | 0.00874       |
# | fps                | 1444          |
# | n_updates          | 14            |
# | policy_entropy     | 24.247044     |
# | policy_loss        | -0.0031910432 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 5.01          |
# | total_timesteps    | 7168          |
# | value_loss         | 770.8747      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017555091  |
# | clipfrac           | 0.005859375   |
# | ep_len_mean        | 22            |
# | ep_reward_mean     | 108           |
# | explained_variance | -0.0014       |
# | fps                | 1350          |
# | n_updates          | 15            |
# | policy_entropy     | 24.267706     |
# | policy_loss        | -0.0053054844 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 5.36          |
# | total_timesteps    | 7680          |
# | value_loss         | 826.7638      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019220104  |
# | clipfrac           | 0.0107421875  |
# | ep_len_mean        | 22.2          |
# | ep_reward_mean     | 109           |
# | explained_variance | 0.00842       |
# | fps                | 1428          |
# | n_updates          | 16            |
# | policy_entropy     | 24.284042     |
# | policy_loss        | -0.0064831898 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 5.74          |
# | total_timesteps    | 8192          |
# | value_loss         | 749.5414      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0016546879   |
# | clipfrac           | 0.0048828125   |
# | ep_len_mean        | 22.5           |
# | ep_reward_mean     | 110            |
# | explained_variance | 0.00872        |
# | fps                | 1393           |
# | n_updates          | 17             |
# | policy_entropy     | 24.299284      |
# | policy_loss        | -0.00044725602 |
# | serial_timesteps   | 2176           |
# | time_elapsed       | 6.1            |
# | total_timesteps    | 8704           |
# | value_loss         | 900.3006       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0013373098  |
# | clipfrac           | 0.001953125   |
# | ep_len_mean        | 22.6          |
# | ep_reward_mean     | 110           |
# | explained_variance | 0.0135        |
# | fps                | 1371          |
# | n_updates          | 18            |
# | policy_entropy     | 24.314983     |
# | policy_loss        | -0.0066559566 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 6.47          |
# | total_timesteps    | 9216          |
# | value_loss         | 749.4458      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0011882772 |
# | clipfrac           | 0.0029296875 |
# | ep_len_mean        | 23           |
# | ep_reward_mean     | 112          |
# | explained_variance | 0.0155       |
# | fps                | 1463         |
# | n_updates          | 19           |
# | policy_entropy     | 24.324202    |
# | policy_loss        | -0.001383873 |
# | serial_timesteps   | 2432         |
# | time_elapsed       | 6.84         |
# | total_timesteps    | 9728         |
# | value_loss         | 772.2362     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0013377944  |
# | clipfrac           | 0.001953125   |
# | ep_len_mean        | 22.9          |
# | ep_reward_mean     | 112           |
# | explained_variance | 0.00706       |
# | fps                | 1482          |
# | n_updates          | 20            |
# | policy_entropy     | 24.322765     |
# | policy_loss        | -0.0022450103 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 7.19          |
# | total_timesteps    | 10240         |
# | value_loss         | 777.0191      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0009410237  |
# | clipfrac           | 0.0014648438  |
# | ep_len_mean        | 23.4          |
# | ep_reward_mean     | 114           |
# | explained_variance | 0.00661       |
# | fps                | 1461          |
# | n_updates          | 21            |
# | policy_entropy     | 24.324646     |
# | policy_loss        | -0.0034534675 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 7.54          |
# | total_timesteps    | 10752         |
# | value_loss         | 815.11487     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0012727974 |
# | clipfrac           | 0.0029296875 |
# | ep_len_mean        | 23.4         |
# | ep_reward_mean     | 114          |
# | explained_variance | 0.00583      |
# | fps                | 1399         |
# | n_updates          | 22           |
# | policy_entropy     | 24.331472    |
# | policy_loss        | -0.005056061 |
# | serial_timesteps   | 2816         |
# | time_elapsed       | 7.89         |
# | total_timesteps    | 11264        |
# | value_loss         | 927.6376     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0010843396  |
# | clipfrac           | 0.001953125   |
# | ep_len_mean        | 24            |
# | ep_reward_mean     | 117           |
# | explained_variance | 0.0171        |
# | fps                | 1443          |
# | n_updates          | 23            |
# | policy_entropy     | 24.338598     |
# | policy_loss        | -0.0054081064 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 8.26          |
# | total_timesteps    | 11776         |
# | value_loss         | 865.9879      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007489738  |
# | clipfrac           | 0.0009765625  |
# | ep_len_mean        | 24.6          |
# | ep_reward_mean     | 120           |
# | explained_variance | 0.00554       |
# | fps                | 1443          |
# | n_updates          | 24            |
# | policy_entropy     | 24.341507     |
# | policy_loss        | 6.8099296e-05 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 8.61          |
# | total_timesteps    | 12288         |
# | value_loss         | 833.78143     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0007470497 |
# | clipfrac           | 0.0009765625 |
# | ep_len_mean        | 24.9         |
# | ep_reward_mean     | 122          |
# | explained_variance | 0.00712      |
# | fps                | 1312         |
# | n_updates          | 25           |
# | policy_entropy     | 24.344967    |
# | policy_loss        | -0.003500171 |
# | serial_timesteps   | 3200         |
# | time_elapsed       | 8.97         |
# | total_timesteps    | 12800        |
# | value_loss         | 771.6488     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0007918022  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 24.3          |
# | ep_reward_mean     | 119           |
# | explained_variance | -0.000303     |
# | fps                | 1453          |
# | n_updates          | 26            |
# | policy_entropy     | 24.3507       |
# | policy_loss        | 0.00013303652 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 9.36          |
# | total_timesteps    | 13312         |
# | value_loss         | 691.4887      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004987543  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 23.6          |
# | ep_reward_mean     | 115           |
# | explained_variance | 0.0183        |
# | fps                | 1414          |
# | n_updates          | 27            |
# | policy_entropy     | 24.352396     |
# | policy_loss        | -0.0030836947 |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 9.71          |
# | total_timesteps    | 13824         |
# | value_loss         | 709.42773     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00065837917 |
# | clipfrac           | 0.00048828125 |
# | ep_len_mean        | 23.5          |
# | ep_reward_mean     | 115           |
# | explained_variance | 0.0017        |
# | fps                | 1479          |
# | n_updates          | 28            |
# | policy_entropy     | 24.349726     |
# | policy_loss        | -0.0019680958 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 10.1          |
# | total_timesteps    | 14336         |
# | value_loss         | 837.53265     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006729684  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 23.3          |
# | ep_reward_mean     | 114           |
# | explained_variance | 0.00372       |
# | fps                | 1470          |
# | n_updates          | 29            |
# | policy_entropy     | 24.345865     |
# | policy_loss        | -0.0040118024 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 10.4          |
# | total_timesteps    | 14848         |
# | value_loss         | 765.6453      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010401316  |
# | clipfrac           | 0.00048828125 |
# | ep_len_mean        | 22.9          |
# | ep_reward_mean     | 112           |
# | explained_variance | 0.0106        |
# | fps                | 1435          |
# | n_updates          | 30            |
# | policy_entropy     | 24.34811      |
# | policy_loss        | -0.0002071581 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 10.8          |
# | total_timesteps    | 15360         |
# | value_loss         | 676.27        |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00035858658 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 23.4          |
# | ep_reward_mean     | 114           |
# | explained_variance | -0.00398      |
# | fps                | 1387          |
# | n_updates          | 31            |
# | policy_entropy     | 24.350914     |
# | policy_loss        | -0.0020624232 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 11.1          |
# | total_timesteps    | 15872         |
# | value_loss         | 787.3672      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00049100374 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 24            |
# | ep_reward_mean     | 117           |
# | explained_variance | -0.00692      |
# | fps                | 1446          |
# | n_updates          | 32            |
# | policy_entropy     | 24.35234      |
# | policy_loss        | -0.0019948296 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 11.5          |
# | total_timesteps    | 16384         |
# | value_loss         | 796.9101      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00048381023 |
# | clipfrac           | 0.00048828125 |
# | ep_len_mean        | 23.6          |
# | ep_reward_mean     | 115           |
# | explained_variance | -0.00164      |
# | fps                | 1471          |
# | n_updates          | 33            |
# | policy_entropy     | 24.356453     |
# | policy_loss        | -0.001669891  |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 11.9          |
# | total_timesteps    | 16896         |
# | value_loss         | 696.8577      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00048636954 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 23.5          |
# | ep_reward_mean     | 114           |
# | explained_variance | -0.00146      |
# | fps                | 1392          |
# | n_updates          | 34            |
# | policy_entropy     | 24.360468     |
# | policy_loss        | -0.003080524  |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 12.2          |
# | total_timesteps    | 17408         |
# | value_loss         | 663.6426      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00037457977 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 24.4          |
# | ep_reward_mean     | 119           |
# | explained_variance | 0.0127        |
# | fps                | 1420          |
# | n_updates          | 35            |
# | policy_entropy     | 24.359167     |
# | policy_loss        | -0.0027243155 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 12.6          |
# | total_timesteps    | 17920         |
# | value_loss         | 933.0482      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00053106085 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 25.9          |
# | ep_reward_mean     | 126           |
# | explained_variance | -0.00148      |
# | fps                | 1449          |
# | n_updates          | 36            |
# | policy_entropy     | 24.361214     |
# | policy_loss        | -0.0044060606 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 12.9          |
# | total_timesteps    | 18432         |
# | value_loss         | 1008.91864    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00045773393 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 26            |
# | ep_reward_mean     | 127           |
# | explained_variance | 0.00106       |
# | fps                | 1437          |
# | n_updates          | 37            |
# | policy_entropy     | 24.364964     |
# | policy_loss        | -0.0023530954 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 13.3          |
# | total_timesteps    | 18944         |
# | value_loss         | 735.6515      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00044660855 |
# | clipfrac           | 0.00048828125 |
# | ep_len_mean        | 26.1          |
# | ep_reward_mean     | 128           |
# | explained_variance | 0.00192       |
# | fps                | 1428          |
# | n_updates          | 38            |
# | policy_entropy     | 24.36924      |
# | policy_loss        | -0.0023103063 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 13.6          |
# | total_timesteps    | 19456         |
# | value_loss         | 715.5425      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024164864 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 25.8          |
# | ep_reward_mean     | 127           |
# | explained_variance | 0.00253       |
# | fps                | 1444          |
# | n_updates          | 39            |
# | policy_entropy     | 24.370232     |
# | policy_loss        | -0.0015042981 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 14            |
# | total_timesteps    | 19968         |
# | value_loss         | 657.62384     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036817355 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 25.1          |
# | ep_reward_mean     | 123           |
# | explained_variance | 0.00807       |
# | fps                | 1421          |
# | n_updates          | 40            |
# | policy_entropy     | 24.370817     |
# | policy_loss        | -0.0006067328 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 14.4          |
# | total_timesteps    | 20480         |
# | value_loss         | 735.0517      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00034490225  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 23.5           |
# | ep_reward_mean     | 115            |
# | explained_variance | 0.00482        |
# | fps                | 1427           |
# | n_updates          | 41             |
# | policy_entropy     | 24.37356       |
# | policy_loss        | -0.00027988403 |
# | serial_timesteps   | 5248           |
# | time_elapsed       | 14.7           |
# | total_timesteps    | 20992          |
# | value_loss         | 693.6704       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00029222708 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 24.2          |
# | ep_reward_mean     | 119           |
# | explained_variance | 0.00555       |
# | fps                | 1404          |
# | n_updates          | 42            |
# | policy_entropy     | 24.374338     |
# | policy_loss        | -0.0010953057 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 15.1          |
# | total_timesteps    | 21504         |
# | value_loss         | 845.84955     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0003626669 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 24.5         |
# | ep_reward_mean     | 120          |
# | explained_variance | 0.00957      |
# | fps                | 1419         |
# | n_updates          | 43           |
# | policy_entropy     | 24.378881    |
# | policy_loss        | -0.002667692 |
# | serial_timesteps   | 5504         |
# | time_elapsed       | 15.4         |
# | total_timesteps    | 22016        |
# | value_loss         | 724.8337     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00018215469 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 24.5          |
# | ep_reward_mean     | 120           |
# | explained_variance | 0.00365       |
# | fps                | 1456          |
# | n_updates          | 44            |
# | policy_entropy     | 24.381872     |
# | policy_loss        | -0.0006434431 |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 15.8          |
# | total_timesteps    | 22528         |
# | value_loss         | 690.1927      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.000330093  |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 24.5         |
# | ep_reward_mean     | 120          |
# | explained_variance | 0.00779      |
# | fps                | 1452         |
# | n_updates          | 45           |
# | policy_entropy     | 24.381887    |
# | policy_loss        | -0.001785023 |
# | serial_timesteps   | 5760         |
# | time_elapsed       | 16.2         |
# | total_timesteps    | 23040        |
# | value_loss         | 740.6104     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00023466587 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 24.6          |
# | ep_reward_mean     | 120           |
# | explained_variance | 0.000186      |
# | fps                | 1404          |
# | n_updates          | 46            |
# | policy_entropy     | 24.382812     |
# | policy_loss        | -0.002162537  |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 16.5          |
# | total_timesteps    | 23552         |
# | value_loss         | 699.3289      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00040881944  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 24.9           |
# | ep_reward_mean     | 122            |
# | explained_variance | 0.00384        |
# | fps                | 1374           |
# | n_updates          | 47             |
# | policy_entropy     | 24.384312      |
# | policy_loss        | -0.00026743388 |
# | serial_timesteps   | 6016           |
# | time_elapsed       | 16.9           |
# | total_timesteps    | 24064          |
# | value_loss         | 749.867        |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00016660629 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 25.7          |
# | ep_reward_mean     | 126           |
# | explained_variance | 0.00343       |
# | fps                | 1399          |
# | n_updates          | 48            |
# | policy_entropy     | 24.38643      |
# | policy_loss        | -0.0010323843 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 17.2          |
# | total_timesteps    | 24576         |
# | value_loss         | 883.85675     |
# --------------------------------------

# %%
model = PPO2.load("humanoid")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render(mode='rgb_array')
